# %%
from study_da.postprocess import aggregate_output_data

# %%
df_final = aggregate_output_data("example_tune_scan/tree.yaml", l_group_by_parameters = ["name base collider", "qx", "qy", "i_oct_b1", "i_oct_b2"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/reader.py:124, in Reader.peek(self, index)
#     123 try:
# --> 124     return self.buffer[self.pointer + index]
#     125 except IndexError:
#
# IndexError: string index out of range
#
# During handling of the above exception, another exception occurred:
#
# ReaderError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_final = aggregate_output_data("example_tune_scan/tree.yaml", l_group_by_parameters = ["name base collider", "qx", "qy", "i_oct_b1", "i_oct_b2"])
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/study_da/postprocess/postprocess.py:187, in aggregate_output_data(path_tree, l_group_by_parameters, generation_of_interest, name_output, write_output, path_output, only_keep_lost_particles, dic_parameters_of_interest, l_parameters_to_keep, name_template_parameters, path_template_parameters)
#     158 """
#     159 Aggregates output data from simulation files.
#     160
#    (...)
#     183     pd.DataFrame: The final aggregated DataFrame.
#     184 """
#     185 logging.info("Analysis of output simulation files started")
# --> 187 dic_tree, _ = load_dic_from_path(path_tree)
#     188 absolute_path_study = dic_tree["absolute_path"]
#     189 dic_all_jobs = ConfigJobs(dic_tree).find_all_jobs()
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/study_da/utils/dic_utils.py:43, in load_dic_from_path(path, ryaml)
#      41 # Load dic
#      42 with open(path, "r") as fid:
# ---> 43     dic = ryaml.load(fid)
#      45 return dic, ryaml
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/main.py:451, in YAML.load(self, stream)
#     449 constructor, parser = self.get_constructor_parser(stream)
#     450 try:
# --> 451     return constructor.get_single_data()
#     452 finally:
#     453     parser.dispose()
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:114, in BaseConstructor.get_single_data(self)
#     112 def get_single_data(self) -> Any:
#     113     # Ensure that the stream contains a single document and construct it.
# --> 114     node = self.composer.get_single_node()
#     115     if node is not None:
#     116         return self.construct_document(node)
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/composer.py:72, in Composer.get_single_node(self)
#      70 document: Any = None
#      71 if not self.parser.check_event(StreamEndEvent):
# ---> 72     document = self.compose_document()
#      74 # Ensure that the stream contains no more documents.
#      75 if not self.parser.check_event(StreamEndEvent):
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/composer.py:94, in Composer.compose_document(self)
#      91 self.parser.get_event()
#      93 # Compose the root node.
# ---> 94 node = self.compose_node(None, None)
#      96 # Drop the DOCUMENT-END event.
#      97 self.parser.get_event()
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/composer.py:130, in Composer.compose_node(self, parent, index)
#     128     node = self.compose_sequence_node(anchor)
#     129 elif self.parser.check_event(MappingStartEvent):
# --> 130     node = self.compose_mapping_node(anchor)
#     131 self.resolver.ascend_resolver()
#     132 return node
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/composer.py:211, in Composer.compose_mapping_node(self, anchor)
#     206 item_key = self.compose_node(node, None)
#     207 # if item_key in node.value:
#     208 #     raise ComposerError("while composing a mapping",
#     209 #             start_event.start_mark,
#     210 #             "found duplicate key", key_event.start_mark)
# --> 211 item_value = self.compose_node(node, item_key)
#     212 # node.value[item_key] = item_value
#     213 node.value.append((item_key, item_value))
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/composer.py:130, in Composer.compose_node(self, parent, index)
#     128     node = self.compose_sequence_node(anchor)
#     129 elif self.parser.check_event(MappingStartEvent):
# --> 130     node = self.compose_mapping_node(anchor)
#     131 self.resolver.ascend_resolver()
#     132 return node
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/composer.py:211, in Composer.compose_mapping_node(self, anchor)
#     206 item_key = self.compose_node(node, None)
#     207 # if item_key in node.value:
#     208 #     raise ComposerError("while composing a mapping",
#     209 #             start_event.start_mark,
#     210 #             "found duplicate key", key_event.start_mark)
# --> 211 item_value = self.compose_node(node, item_key)
#     212 # node.value[item_key] = item_value
#     213 node.value.append((item_key, item_value))
#
#     [... skipping similar frames: Composer.compose_mapping_node at line 211 (1 times), Composer.compose_node at line 130 (1 times)]
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/composer.py:130, in Composer.compose_node(self, parent, index)
#     128     node = self.compose_sequence_node(anchor)
#     129 elif self.parser.check_event(MappingStartEvent):
# --> 130     node = self.compose_mapping_node(anchor)
#     131 self.resolver.ascend_resolver()
#     132 return node
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/composer.py:211, in Composer.compose_mapping_node(self, anchor)
#     206 item_key = self.compose_node(node, None)
#     207 # if item_key in node.value:
#     208 #     raise ComposerError("while composing a mapping",
#     209 #             start_event.start_mark,
#     210 #             "found duplicate key", key_event.start_mark)
# --> 211 item_value = self.compose_node(node, item_key)
#     212 # node.value[item_key] = item_value
#     213 node.value.append((item_key, item_value))
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/composer.py:106, in Composer.compose_node(self, parent, index)
#     105 def compose_node(self, parent: Any, index: Any) -> Any:
# --> 106     if self.parser.check_event(AliasEvent):
#     107         event = self.parser.get_event()
#     108         alias = event.anchor
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/parser.py:141, in Parser.check_event(self, *choices)
#     139 if self.current_event is None:
#     140     if self.state:
# --> 141         self.current_event = self.state()
#     142 if self.current_event is not None:
#     143     if not choices:
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/parser.py:631, in Parser.parse_block_mapping_value(self)
#     629 token = self.scanner.get_token()
#     630 # value token might have post comment move it to e.g. block
# --> 631 if self.scanner.check_token(ValueToken):
#     632     self.move_token_comment(token)
#     633 else:
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/scanner.py:1735, in RoundTripScanner.check_token(self, *choices)
#    1733 while self.need_more_tokens():
#    1734     self.fetch_more_tokens()
# -> 1735 self._gather_comments()
#    1736 if len(self.tokens) > 0:
#    1737     if not choices:
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/scanner.py:1775, in RoundTripScanner._gather_comments(self)
#    1773 # pull in post comment on e.g. ':'
#    1774 if not self.done and len(self.tokens) < 2:
# -> 1775     self.fetch_more_tokens()
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/scanner.py:310, in Scanner.fetch_more_tokens(self)
#     308 # It must be a plain scalar then.
#     309 if self.check_plain():
# --> 310     return self.fetch_plain()
#     312 # No? It's an error. Let's produce a nice error message.
#     313 raise ScannerError(
#     314     'while scanning for the next token',
#     315     None,
#     316     f'found character {ch!r} that cannot start any token',
#     317     self.reader.get_mark(),
#     318 )
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/scanner.py:715, in Scanner.fetch_plain(self)
#     713 self.allow_simple_key = False
#     714 # Scan and add SCALAR. May change `allow_simple_key`.
# --> 715 self.tokens.append(self.scan_plain())
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/scanner.py:1511, in Scanner.scan_plain(self)
#    1509     break
#    1510 while True:
# -> 1511     ch = srp(length)
#    1512     if False and ch == ':' and srp(length + 1) == ',':
#    1513         break
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/reader.py:126, in Reader.peek(self, index)
#     124     return self.buffer[self.pointer + index]
#     125 except IndexError:
# --> 126     self.update(index + 1)
#     127     return self.buffer[self.pointer + index]
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/reader.py:252, in Reader.update(self, length)
#     250     data = self.raw_buffer
#     251     converted = len(data)
# --> 252 self.check_printable(data)
#     253 self.buffer += data
#     254 self.raw_buffer = self.raw_buffer[converted:]
#
# File /afs/cern.ch/work/c/cdroin/private/study-DA/.venv/lib/python3.11/site-packages/ruamel/yaml/reader.py:221, in Reader.check_printable(self, data)
#     219 start, character = non_printable_match
#     220 position = self.index + (len(self.buffer) - self.pointer) + start
# --> 221 raise ReaderError(
#     222     self.name,
#     223     position,
#     224     ord(character),
#     225     'unicode',
#     226     'special characters are not allowed',
#     227 )
#
# ReaderError: unacceptable character #x0000: special characters are not allowed
#   in "example_tune_scan/tree.yaml", position 524288
